# %% [markdown]
# <a href="https://colab.research.google.com/github/ErikFantomex/CIAD-/blob/main/Ciad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from pandas.core.frame import DataFrame

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Campeche = pd.read_csv('/content/drive/MyDrive/agro_proyecto/DS-AgroEcolgógica/08042021-pv21-estado-4.csv',sep = ",")
Chiapas = pd.read_csv('/content/drive/MyDrive/agro_proyecto/DS-AgroEcolgógica/08042021-pv21-estado-7.csv',sep = ",")
Chihuahua= pd.read_csv('/content/drive/MyDrive/agro_proyecto/DS-AgroEcolgógica/08042021-pv21-estado-8.csv',sep = ",")
Guanajuato= pd.read_csv('/content/drive/MyDrive/agro_proyecto/DS-AgroEcolgógica/08042021-pv21-estado-11.csv',sep = ",")
Hidalgo= pd.read_csv('/content/drive/MyDrive/agro_proyecto/DS-AgroEcolgógica/08042021-pv21-estado-13.csv',sep = ",")
Jalisco=pd.read_csv('/content/drive/MyDrive/agro_proyecto/DS-AgroEcolgógica/08042021-pv21-estado-14.csv',sep = ",")
Mexico = pd.read_csv('/content/drive/MyDrive/agro_proyecto/DS-AgroEcolgógica/08042021-pv21-estado-15.csv',sep = ",")
Michoacan = pd.read_csv('/content/drive/MyDrive/agro_proyecto/DS-AgroEcolgógica/08042021-pv21-estado-16.csv',sep = ",")
Oaxaca = pd.read_csv('/content/drive/MyDrive/agro_proyecto/DS-AgroEcolgógica/08042021-pv21-estado-20.csv',sep = ",")
Sinaloa = pd.read_csv('/content/drive/MyDrive/agro_proyecto/DS-AgroEcolgógica/08042021-pv21-estado-25.csv',sep = ",")
Sonora = pd.read_csv('/content/drive/MyDrive/agro_proyecto/DS-AgroEcolgógica/08042021-pv21-estado-26.csv',sep = ",")
Tamaulipas = pd.read_csv('/content/drive/MyDrive/agro_proyecto/DS-AgroEcolgógica/08042021-pv21-estado-28.csv',sep = ",")
Tlaxcala = pd.read_csv('/content/drive/MyDrive/agro_proyecto/DS-AgroEcolgógica/08042021-pv21-estado-29.csv',sep = ",")
Veracruz = pd.read_csv('/content/drive/MyDrive/agro_proyecto/DS-AgroEcolgógica/08042021-pv21-estado-30.csv',sep = ",")

# %% [markdown]
# **Prueba**

# %%
Sonora.info()

# %% [markdown]
# #Otra manera de hacerlo es con query

# %%
Sonora.query('CULTIVO=="MAIZ GRANO" or CULTIVO=="MILPA"')

#df1 = df.query('a>30 and c>60')

#query multiple columns

#df1 = df.query('a>50 or c>60')
# Out:
#       DELEGACIÓN NOMBRE DE LA DELEGACIÓN  DDR         NOMBRE DEL DDR  CADER  \
# 0             26                  SONORA  139                CABORCA      2
# 1             26                  SONORA  139                CABORCA      2
# 2             26                  SONORA  139                CABORCA      3
# 3             26                  SONORA  139                CABORCA      3
# 67            26                  SONORA  140              MAGDALENA      5
# ...          ...                     ...  ...                    ...    ...
# 4983          26                  SONORA  149                NAVOJOA     33
# 4984          26                  SONORA  149                NAVOJOA     33
# 4985          26                  SONORA  149                NAVOJOA     33
# 4986          26                  SONORA  149                NAVOJOA     33
# 5003          26                  SONORA  193  SAN LUIS RIO COLORADO      4
#
# ...

# %%
Sonora.head()

# %%
#Filtracion de datos
Sonora_maizgrano=Sonora.loc[Sonora['CULTIVO'] == "MAIZ GRANO"]
#Sonora.filter(like="MAIZ GRANO")
Sonora_maizgrano
# Out:
#       DELEGACIÓN NOMBRE DE LA DELEGACIÓN  DDR         NOMBRE DEL DDR  CADER  \
# 0             26                  SONORA  139                CABORCA      2
# 1             26                  SONORA  139                CABORCA      2
# 2             26                  SONORA  139                CABORCA      3
# 3             26                  SONORA  139                CABORCA      3
# 67            26                  SONORA  140              MAGDALENA      5
# ...          ...                     ...  ...                    ...    ...
# 4983          26                  SONORA  149                NAVOJOA     33
# 4984          26                  SONORA  149                NAVOJOA     33
# 4985          26                  SONORA  149                NAVOJOA     33
# 4986          26                  SONORA  149                NAVOJOA     33
# 5003          26                  SONORA  193  SAN LUIS RIO COLORADO      4
#
# ...

# %%
Sonora_maizgrano.tail()
# Out:
#       DELEGACIÓN NOMBRE DE LA DELEGACIÓN  DDR         NOMBRE DEL DDR  CADER  \
# 4983          26                  SONORA  149                NAVOJOA     33
# 4984          26                  SONORA  149                NAVOJOA     33
# 4985          26                  SONORA  149                NAVOJOA     33
# 4986          26                  SONORA  149                NAVOJOA     33
# 5003          26                  SONORA  193  SAN LUIS RIO COLORADO      4
#
#            NOMBRE DEL CADER  MUNICIPIO   NOMBRE DEL MUNICIPIO  EJIDO  \
# 4983                 ALAMOS          3                 ALAMOS    859
# 4984                 ALAMOS          3                 ALAMOS    859
# 4985                 ALAMOS          3                 ALAMOS    859
# 4986                 ALAMOS          3                 ALAMOS    859
# 5003  SAN LUIS RIO COLORADO         55  SAN LUIS RÍO COLORADO    738
#
#      NOMBRE DEL EJIDO  ... SUPERFICIE APOYADA  MONTO APOYADO TIPO PAGO CICLO  \
# ...

# %% [markdown]
# # Filtrado de datos#

# %%
#milpa o maiz grano
#Sonora_maizgrano=Sonora.loc[Sonora['CULTIVO'] == "MAIZ GRANO"]
#df.loc[(df['column_name'] >= A) & (df['column_name'] <= B)]
Sonora_maiz_grano_milpa=Sonora.loc[(Sonora['CULTIVO'] == "MAIZ GRANO")|(Sonora['CULTIVO'] == "MILPA")]

# %%
Sonora_maiz_grano_milpa
# Out:
#       DELEGACIÓN NOMBRE DE LA DELEGACIÓN  DDR         NOMBRE DEL DDR  CADER  \
# 0             26                  SONORA  139                CABORCA      2
# 1             26                  SONORA  139                CABORCA      2
# 2             26                  SONORA  139                CABORCA      3
# 3             26                  SONORA  139                CABORCA      3
# 67            26                  SONORA  140              MAGDALENA      5
# ...          ...                     ...  ...                    ...    ...
# 4983          26                  SONORA  149                NAVOJOA     33
# 4984          26                  SONORA  149                NAVOJOA     33
# 4985          26                  SONORA  149                NAVOJOA     33
# 4986          26                  SONORA  149                NAVOJOA     33
# 5003          26                  SONORA  193  SAN LUIS RIO COLORADO      4
#
# ...

# %%
Sonora_maiz_grano_milpa.tail(40)

# %%
# Seleccionar MAIZ GRANO, MIlPA para beneficiarios con al menos cinco hectáreas 
SonoraMGM5mas = Sonora.loc[((Sonora['CULTIVO'] == "MAIZ GRANO")|(Sonora['CULTIVO'] == "MILPA"))&(Sonora['SUPERFICIE APOYADA']>=5.0)]
SonoraMGM5mas.shape
# Out:
# (1067, 25)

# %%
# Desplegar los distintos valores de una variable con la funcion unique()
unique_values =  np.unique(Sonora[['CULTIVO']].values)
print(unique_values)
# Out:
# ['AJONJOLI GRANO' 'AVENA GRANO' 'CACAHUATE' 'CEBADA GRANO' 'FRIJOL'
#  'MAIZ GRANO' 'MILPA' 'SORGO GRANO']

# %%
SonoraMGM5mas.head()
# Out:
#     DELEGACIÓN NOMBRE DE LA DELEGACIÓN  DDR NOMBRE DEL DDR  CADER  \
# 0           26                  SONORA  139        CABORCA      2
# 1           26                  SONORA  139        CABORCA      2
# 2           26                  SONORA  139        CABORCA      3
# 3           26                  SONORA  139        CABORCA      3
# 67          26                  SONORA  140      MAGDALENA      5
#
#    NOMBRE DEL CADER  MUNICIPIO NOMBRE DEL MUNICIPIO  EJIDO NOMBRE DEL EJIDO  \
# 0           CABORCA         17              CABORCA      0      P,PROPIEDAD
# 1           CABORCA         17              CABORCA      0      P,PROPIEDAD
# 2              ATIL         60                SÁRIC      0      P,PROPIEDAD
# 3              ATIL         60                SÁRIC      0      P,PROPIEDAD
# 67        MAGDALENA         36            MAGDALENA      0      P,PROPIEDAD
#
#     ... SUPERFICIE APOYADA  MONTO APOYADO      TIPO PAGO CICLO     CULTIVO  \
# ...

# %% [markdown]
# #caso general acabado sigue hacer con los demas#

# %%
CampecheMGM5mas =Campeche.loc[((Campeche['CULTIVO']=="MAIZ GRANO")|(Campeche['CULTIVO']=="MILPA"))&(Campeche['SUPERFICIE APOYADA']>=5.0)]
CampecheMGM5mas.drop_duplicates()
CampecheMGM5mas.shape
# Out:
# (3340, 25)

# %%
CampecheMGM5mas.head()
# Out:
#      DELEGACIÓN NOMBRE DE LA DELEGACIÓN  DDR NOMBRE DEL DDR  CADER  \
# 28            4                CAMPECHE    8    HECELCHAKAN      1
# 41            4                CAMPECHE    8    HECELCHAKAN      1
# 73            4                CAMPECHE    8    HECELCHAKAN      1
# 142           4                CAMPECHE    8    HECELCHAKAN      1
# 189           4                CAMPECHE    8    HECELCHAKAN      1
#
#     NOMBRE DEL CADER  MUNICIPIO NOMBRE DEL MUNICIPIO  EJIDO NOMBRE DEL EJIDO  \
# 28          CALKINI-          1              CALKINÍ      1            BECAL
# 41          CALKINI-          1              CALKINÍ      1            BECAL
# 73          CALKINI-          1              CALKINÍ      1            BECAL
# 142         CALKINI-          1              CALKINÍ      1            BECAL
# 189         CALKINI-          1              CALKINÍ      2          CALKINI
#
#      ... SUPERFICIE APOYADA  MONTO APOYADO      TIPO PAGO CICLO     CULTIVO  \
# ...

# %%
ChiapasMGM5mas =Chiapas.loc[((Chiapas['CULTIVO']=="MAIZ GRANO")|(Chiapas['CULTIVO']=="MILPA"))&(Chiapas['SUPERFICIE APOYADA']>=5)]
ChihuahuaMGM5mas= Chihuahua.loc[((Chihuahua['CULTIVO']=="MAIZ GRANO")|(Chihuahua['CULTIVO']=="MILPA"))&(Chihuahua['SUPERFICIE APOYADA']>=5)]
GuanajuatoMGM5mas= Guanajuato.loc[((Guanajuato['CULTIVO']=="MAIZ GRANO")|(Guanajuato['CULTIVO']=="MILPA"))&(Guanajuato['SUPERFICIE APOYADA']>=5)]
HidalgoMGM5mas =Hidalgo.loc[((Hidalgo['CULTIVO']=="MAIZ GRANO")|(Hidalgo['CULTIVO']=="MILPA"))&(Hidalgo['SUPERFICIE APOYADA']>=5)]
JaliscoMGM5mas =Jalisco.loc[((Jalisco['CULTIVO']=="MAIZ GRANO")|(Jalisco['CULTIVO']=="MILPA"))&(Jalisco['SUPERFICIE APOYADA']>=5)]
MexicoMGM5mas =Mexico.loc[((Mexico['CULTIVO']=="MAIZ GRANO")|(Mexico['CULTIVO']=="MILPA"))&(Mexico['SUPERFICIE APOYADA']>=5)]
MichoacanMGM5mas= Michoacan.loc[((Michoacan['CULTIVO']=="MAIZ GRANO")|(Michoacan['CULTIVO']=="MILPA"))&(Michoacan['SUPERFICIE APOYADA']>=5)]
OaxacaMGM5mas =Oaxaca.loc[((Oaxaca['CULTIVO']=="MAIZ GRANO")|(Oaxaca['CULTIVO']=="MILPA"))&(Oaxaca['SUPERFICIE APOYADA']>=5)]
SinaloaMGM5mas =Sinaloa.loc[((Sinaloa['CULTIVO']=="MAIZ GRANO")|(Sinaloa['CULTIVO']=="MILPA"))&(Sinaloa['SUPERFICIE APOYADA']>=5)]
TamaulipasMGM5mas= Tamaulipas.loc[((Tamaulipas['CULTIVO']=="MAIZ GRANO")|(Tamaulipas['CULTIVO']=="MILPA"))&(Tamaulipas['SUPERFICIE APOYADA']>=5)]
TlaxcalaMGM5mas =Tlaxcala.loc[((Tlaxcala['CULTIVO']=="MAIZ GRANO")|(Tlaxcala['CULTIVO']=="MILPA"))&(Tlaxcala['SUPERFICIE APOYADA']>=5)]
VeracruzMGM5mas =Veracruz.loc[((Veracruz['CULTIVO']=="MAIZ GRANO")|(Veracruz['CULTIVO']=="MILPA"))&(Veracruz['SUPERFICIE APOYADA']>=5)]

# %% [markdown]
# *shape*

# %%
CampecheMGM5mas.shape
# Out:
# (3340, 25)

# %%
ChiapasMGM5mas.shape
# Out:
# (22535, 25)

# %%
ChihuahuaMGM5mas.shape
# Out:
# (6610, 25)

# %%
GuanajuatoMGM5mas.shape
# Out:
# (6127, 25)

# %%
HidalgoMGM5mas.shape
# Out:
# (792, 25)

# %%
JaliscoMGM5mas.shape
# Out:
# (12138, 25)

# %%
MexicoMGM5mas.shape
# Out:
# (2960, 25)

# %%
MichoacanMGM5mas.shape
# Out:
# (12579, 25)

# %%
OaxacaMGM5mas.shape
# Out:
# (1657, 25)

# %%
SinaloaMGM5mas.shape
# Out:
# (7346, 25)

# %%
TamaulipasMGM5mas.shape
# Out:
# (3940, 25)

# %%
TlaxcalaMGM5mas.shape
# Out:
# (2294, 25)

# %%
VeracruzMGM5mas.shape
# Out:
# (5302, 25)

# %%
# Out:
# (16714, 25)

# %% [markdown]
# *Juntando bases de datos*

# %%
RegCentro=pd.concat([JaliscoMGM5mas,GuanajuatoMGM5mas,HidalgoMGM5mas,MexicoMGM5mas,MichoacanMGM5mas,TlaxcalaMGM5mas ])

RegCentro.head()
# Out:
#     DELEGACIÓN NOMBRE DE LA DELEGACIÓN  DDR NOMBRE DEL DDR  CADER  \
# 0           14                 JALISCO   65        ZAPOPAN      1
# 1           14                 JALISCO   65        ZAPOPAN      1
# 2           14                 JALISCO   65        ZAPOPAN      1
# 3           14                 JALISCO   65        ZAPOPAN      1
# 10          14                 JALISCO   65        ZAPOPAN      1
#
#    NOMBRE DEL CADER  MUNICIPIO NOMBRE DEL MUNICIPIO  EJIDO  \
# 0       PALOS ALTOS         29               CUQUÍO    337
# 1       PALOS ALTOS         29               CUQUÍO    337
# 2       PALOS ALTOS         29               CUQUÍO    337
# 3       PALOS ALTOS         29               CUQUÍO    337
# 10      PALOS ALTOS         29               CUQUÍO    337
#
#       NOMBRE DEL EJIDO  ... SUPERFICIE APOYADA  MONTO APOYADO TIPO PAGO CICLO  \
# 0   ATEMAJAC DEL VALLE  ...               5.00        10000.0  DEPOSITO  PV21
# ...

# %%
RegSur = pd.concat([OaxacaMGM5mas,ChiapasMGM5mas,VeracruzMGM5mas,CampecheMGM5mas])
RegSur.head()
# Out:
#      DELEGACIÓN NOMBRE DE LA DELEGACIÓN  DDR        NOMBRE DEL DDR  CADER  \
# 0            20                  OAXACA  104  HUAJUAPAN  (MIXTECA)      1
# 61           20                  OAXACA  104  HUAJUAPAN  (MIXTECA)      1
# 75           20                  OAXACA  104  HUAJUAPAN  (MIXTECA)      1
# 182          20                  OAXACA  104  HUAJUAPAN  (MIXTECA)      1
# 187          20                  OAXACA  104  HUAJUAPAN  (MIXTECA)      1
#
#     NOMBRE DEL CADER  MUNICIPIO                 NOMBRE DEL MUNICIPIO  EJIDO  \
# 0          HUAJUAPAN         11                            CALIHUALÁ    856
# 61         HUAJUAPAN         16               COICOYÁN DE LAS FLORES    867
# 75         HUAJUAPAN         16               COICOYÁN DE LAS FLORES   1662
# 182        HUAJUAPAN         39  HEROICA CIUDAD DE HUAJUAPAN DE LEÓN   1681
# 187        HUAJUAPAN         39  HEROICA CIUDAD DE HUAJUAPAN DE LEÓN   1682
#
# ...

# %%
RegNoroeste = pd.concat([SonoraMGM5mas,SinaloaMGM5mas,ChihuahuaMGM5mas,TamaulipasMGM5mas])
RegNoroeste.head()
# Out:
#     DELEGACIÓN NOMBRE DE LA DELEGACIÓN  DDR NOMBRE DEL DDR  CADER  \
# 0           26                  SONORA  139        CABORCA      2
# 1           26                  SONORA  139        CABORCA      2
# 2           26                  SONORA  139        CABORCA      3
# 3           26                  SONORA  139        CABORCA      3
# 67          26                  SONORA  140      MAGDALENA      5
#
#    NOMBRE DEL CADER  MUNICIPIO NOMBRE DEL MUNICIPIO  EJIDO NOMBRE DEL EJIDO  \
# 0           CABORCA         17              CABORCA      0      P,PROPIEDAD
# 1           CABORCA         17              CABORCA      0      P,PROPIEDAD
# 2              ATIL         60                SÁRIC      0      P,PROPIEDAD
# 3              ATIL         60                SÁRIC      0      P,PROPIEDAD
# 67        MAGDALENA         36            MAGDALENA      0      P,PROPIEDAD
#
#     ... SUPERFICIE APOYADA  MONTO APOYADO      TIPO PAGO CICLO     CULTIVO  \
# ...

# %%
RegCentro.shape
# Out:
# (36890, 25)

# %%
RegNoroeste.shape
# Out:
# (18963, 25)

# %%
RegSur.shape
# Out:
# (32834, 25)

# %% [markdown]
# # Mega base de datos

# %%
RegEstudio=pd.concat([RegNoroeste,RegCentro,RegSur ])

RegEstudio
# Out:
#        DELEGACIÓN NOMBRE DE LA DELEGACIÓN  DDR NOMBRE DEL DDR  CADER  \
# 0              26                  SONORA  139        CABORCA      2
# 1              26                  SONORA  139        CABORCA      2
# 2              26                  SONORA  139        CABORCA      3
# 3              26                  SONORA  139        CABORCA      3
# 67             26                  SONORA  140      MAGDALENA      5
# ...           ...                     ...  ...            ...    ...
# 18940           4                CAMPECHE   11      ESCARCEGA     10
# 18942           4                CAMPECHE   11      ESCARCEGA     10
# 18949           4                CAMPECHE   11      ESCARCEGA     10
# 18966           4                CAMPECHE   11      ESCARCEGA     10
# 18997           4                CAMPECHE   11      ESCARCEGA     10
#
#       NOMBRE DEL CADER  MUNICIPIO NOMBRE DEL MUNICIPIO  EJIDO  \
# 0              CABORCA         17              CABORCA      0
# ...

# %% [markdown]
# > Bloc con sangría

# %%
RegEstudio.to_csv('RegionesEstudio_EDOS_MPIO.csv')

# %%
unique_values =  np.unique(RegEstudio[['NOMBRE DE LA DELEGACIÓN']].values)
print(unique_values)
# Out:
# ['CAMPECHE' 'CHIAPAS' 'CHIHUAHUA' 'GUANAJUATO' 'HIDALGO' 'JALISCO'
#  'MEXICO' 'MICHOACAN DE OCAMPO' 'OAXACA' 'SINALOA' 'SONORA' 'TAMAULIPAS'
#  'TLAXCALA' 'VERACRUZ DE IGNACIO DE LA LLAVE']

# %%
RegEstudio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88687 entries, 0 to 18997
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   DELEGACIÓN                      88687 non-null  int64
#  1   NOMBRE DE LA DELEGACIÓN         88687 non-null  object
#  2   DDR                             88687 non-null  int64
#  3   NOMBRE DEL DDR                  88687 non-null  object
#  4   CADER                           88687 non-null  int64
#  5   NOMBRE DEL CADER                88687 non-null  object
#  6   MUNICIPIO                       88687 non-null  int64
#  7   NOMBRE DEL MUNICIPIO            88687 non-null  object
#  8   EJIDO                           88687 non-null  int64
#  9   NOMBRE DEL EJIDO                88687 non-null  object
#  10  TIPO DE PERSONA                 88687 non-null  object
#  11  ID SURI                         88687 non-null  int64
# ...

# %% [markdown]
# # Eliminar duplicados en la columna ID SURI

# %%
RegEstudio1=RegEstudio.drop_duplicates(subset='ID SURI')

# %%
RegEstudio1.to_csv('RegionesEstudio1_EDOS_MPIO.csv')

# %% [markdown]
# # Graficacion

# %%
# Figuras en linea
import matplotlib
# %matplotlib inline


import matplotlib.pyplot as plt
#plt.rcParams['figure.figsize'] = (15, 5)      # Tamaño de las gráficas

matplotlib.style.use('ggplot')

# %%
#RegEstudio.plot(figsize=(300,10))
